# %%
from wikipedia2vec import Wikipedia2Vec

# Load model
MODEL = "models/ZHWIKI"
wiki2vec = Wikipedia2Vec.load(MODEL)

# %%
from bias import *

# Original Words Pairs and Neutral Words
# PCA score was [0.41397827, 0.33627759, 0.09148767, 0.06558527, 0.0426147]

WORD_PAIRS = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'], 
              ['女王', '国王'], ['妻子', '丈夫'], ['女士', '男士']]

NEUTRAL_WORDS = ['护士', '教师', '作家', '工程师', '科学家', '经理', 
                 '司机', '银行家', '电工', '酒保', '音乐家', '艺术家',
                 '厨师', '制片人', '法官', '喜剧演员', '发明家', '工人',
                 '战士', '记者', '学生',  '运动员',  '演员',  '总督', 
                 '农民', '人', '律师', '冒险家', '助手', '大使', 
                 '分析员', '宇航员',  '天文学家',  '生物学家']

# %%
compute_explained_variance_ratio(wiki2vec, WORD_PAIRS, 5)
# Out:
# array([0.41397827, 0.33627759, 0.09148767, 0.06558527, 0.0426147 ])

# %%
WORD_PAIRS_FLAT = [item for pair in WORD_PAIRS for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, WORD_PAIRS, 0)
# Out:
# [('女人', -0.1775168445489237),
#  ('男人', -0.19876652395412925),
#  ('女儿', 0.2457352014390297),
#  ('儿子', 0.42517810138371004),
#  ('母亲', 0.2510986867181241),
#  ('父亲', 0.4114486879347821),
#  ('女孩', -0.26971668348784106),
#  ('男孩', -0.1698664730663668),
#  ('女王', -0.30572204720673357),
#  ('国王', 0.32808199831531665),
#  ('妻子', 0.1898208639266825),
#  ('丈夫', 0.11326991958487626),
#  ('女士', 0.10797694928952563),
#  ('男士', -0.5190406019886186)]

# %%
bias_by_word(wiki2vec, NEUTRAL_WORDS, WORD_PAIRS, 0)
# Out:
# [('护士', -0.0010667738245364537),
#  ('教师', 0.19528780001428794),
#  ('作家', 0.10277659719654618),
#  ('工程师', 0.23291201906231937),
#  ('科学家', 0.17254991820621518),
#  ('经理', 0.2192221175449791),
#  ('司机', 0.022548737493409417),
#  ('银行家', 0.23680850160930136),
#  ('电工', 0.18061661856642178),
#  ('酒保', -0.1713078873537371),
#  ('音乐家', 0.23503139361092526),
#  ('艺术家', 0.14519167774922853),
#  ('厨师', 0.05528912844169695),
#  ('制片人', 0.1523658307716899),
#  ('法官', 0.020676330420701824),
#  ('喜剧演员', 0.05529331081656242),
#  ('发明家', 0.12733884063753392),
#  ('工人', -0.05736198447090999),
#  ('战士', 0.06471906746253575),
#  ('记者', 0.11974315382988182),
#  ('学生', 0.11734346405234203),
#  ('运动员', 0.14936847650194168),
#  ('演员', 0.03777392656375452),
#  ('总督', 0.2610610822628554),
#  ('农民', 0.10204730333293299),
#  ('人', 0.07467208531575323),
#  ('律师', 0.19310564095783886),
#  ('冒险家', 0.030332204833870148),
#  ('助手', 0.13096927805134093),
#  ('大使', 0.04408764907596139),
# ...

# %%
# Changing queeen_king pair ['女王', '国王'] to ['皇后', '国王']

# PCA score improved [0.4558215, 0.31696622, 0.09068795, 0.05482144, 0.03625121]
# 0.41397827 -> 0.4558215

CHANGING_QUEEN_KING = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'], 
                       ['皇后', '国王'], ['妻子', '丈夫'], ['女士', '男士']]
compute_explained_variance_ratio(wiki2vec, CHANGING_QUEEN_KING, 5)
# Out:
# array([0.4558215 , 0.31696622, 0.09068795, 0.05482144, 0.03625121])

# %%
WORD_PAIRS_FLAT = [item for pair in CHANGING_QUEEN_KING for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, CHANGING_QUEEN_KING, 0)
# Out:
# [('女人', 0.005745245992925551),
#  ('男人', -0.03280406706680563),
#  ('女儿', -0.0946537387563016),
#  ('儿子', -0.18813703233210116),
#  ('母亲', -0.04672482450429556),
#  ('父亲', -0.11078682079207142),
#  ('女孩', 0.031944753573130175),
#  ('男孩', 0.05679907460366805),
#  ('皇后', 0.4907790292780738),
#  ('国王', -0.48100434156202243),
#  ('妻子', 0.06916559849880122),
#  ('丈夫', 0.08211699359964907),
#  ('女士', 0.0733137917377105),
#  ('男士', -0.06781704759400685)]

# %%
# Changing madam_sir pair ['女士', '男士'] to ['女士', '先生']
# PCA score improved [0.45864364, 0.26965182, 0.08614243, 0.07340476, 0.05180203]
# 0.41397827 -> 0.45864364

CHANGING_MADAM_SIR = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'], 
                      ['女王', '国王'], ['妻子', '丈夫'], ['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, CHANGING_MADAM_SIR, 5)
# Out:
# array([0.45864364, 0.26965182, 0.08614243, 0.07340476, 0.05180203])

# %%
WORD_PAIRS_FLAT = [item for pair in CHANGING_MADAM_SIR for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, CHANGING_MADAM_SIR, 0)
# Out:
# [('女人', -0.11025840341448245),
#  ('男人', -0.10208654589724028),
#  ('女儿', 0.2102471881431539),
#  ('儿子', 0.44853011289239203),
#  ('母亲', 0.20537458216693052),
#  ('父亲', 0.3609617853211221),
#  ('女孩', -0.2039158339501906),
#  ('男孩', -0.09868241067622616),
#  ('女王', -0.33713289005374314),
#  ('国王', 0.47703882013366206),
#  ('妻子', 0.02795818098863708),
#  ('丈夫', -0.02023165306078389),
#  ('女士', -0.15425506874295453),
#  ('先生', 0.08980711612024114)]

# %%
# Changing queeen_king pair ['女王', '国王'] to ['皇后', '国王'] &
# Changing madam_sir pair ['女士', '男士'] to ['女士', '先生']

# PCA score improved [0.52368772, 0.24001874, 0.07809053, 0.06192639, 0.04259698]
# 0.41397827 -> 0.52368772

CHANGING_QUEEN_KING_AND_MADAM_SIR = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'], 
                                     ['皇后', '国王'], ['妻子', '丈夫'], ['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, CHANGING_QUEEN_KING_AND_MADAM_SIR, 5)
# Out:
# array([0.52368772, 0.24001874, 0.07809053, 0.06192639, 0.04259698])

# %%
WORD_PAIRS_FLAT = [item for pair in CHANGING_QUEEN_KING_AND_MADAM_SIR for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, CHANGING_QUEEN_KING_AND_MADAM_SIR, 0)
# Out:
# [('女人', -0.03029161432344982),
#  ('男人', 0.004412090351981008),
#  ('女儿', 0.10513721580562982),
#  ('儿子', 0.20694922324209178),
#  ('母亲', 0.05842482991651326),
#  ('父亲', 0.13579832537728254),
#  ('女孩', -0.06193148104998914),
#  ('男孩', -0.0780217958428188),
#  ('皇后', -0.49680723153808426),
#  ('国王', 0.4789453421068469),
#  ('妻子', -0.049287749961122604),
#  ('丈夫', -0.06890695861498404),
#  ('女士', -0.05293107526488614),
#  ('先生', -0.029968550995000877)]

# %%
# Removing wife-husband pair ['妻子', '丈夫']
# PCA score improved, [0.53810239, 0.2466353 , 0.0800649 , 0.06308138, 0.04377524]
# 0.52368772 -> 0.53810239 = 0.01441467

REMOVING_WIFE_HUSBAND = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'],
                         ['皇后', '国王'], ['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, REMOVING_WIFE_HUSBAND, 5)
# Out:
# array([0.53810239, 0.2466353 , 0.0800649 , 0.06308138, 0.04377524])

# %%
WORD_PAIRS_FLAT = [item for pair in REMOVING_WIFE_HUSBAND for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, REMOVING_WIFE_HUSBAND, 0)
# Out:
# [('女人', -0.030184027426574823),
#  ('男人', 0.004581695959999669),
#  ('女儿', 0.10416679114146656),
#  ('儿子', 0.2058807885564114),
#  ('母亲', 0.05790514281110943),
#  ('父亲', 0.1353372422238839),
#  ('女孩', -0.06193409346439008),
#  ('男孩', -0.07811416183866722),
#  ('皇后', -0.49683192500392176),
#  ('国王', 0.4789258116886004),
#  ('女士', -0.05353887048589961),
#  ('先生', -0.030355712075617356)]

# %%
# Adding 19 new pairs
# PCA score is worse, [0.26630917, 0.12938679, 0.09135412, 0.06923946, 0.05961088]

# Proposed New Words Pairs and Neutral Words
NEW_WORD_PAIRS = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'], ['皇后', '国王'], ['妻子', '丈夫'], ['女士', '先生'],
                  
# Expanded word pairs              
              ['外婆', '外公'], ['姥姥', '姥爷'], ['奶奶', '爷爷'], ['舅妈', '舅舅'], ['阿姨', '姨父'], 
              ['伯母', '伯伯'], ['婶婶', '叔叔'], ['姑姑', '姑父'], ['表姐', '表哥'], ['表妹', '表弟'], 
              ['堂姐', '堂哥'], ['堂妹', '堂弟'], ['姐姐', '哥哥'], ['妹妹', '弟弟'], ['侄女', '侄子'], 
              ['外甥女', '外甥'],['婆婆', '公公'],['岳母', '岳父'], ['继母', '继父']]
compute_explained_variance_ratio(wiki2vec, NEW_WORD_PAIRS, 5)
# Out:
# array([0.25062166, 0.12660373, 0.10016147, 0.07137507, 0.06026293])

# %%
WORD_PAIRS_FLAT = [item for pair in NEW_WORD_PAIRS for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, NEW_WORD_PAIRS, 0)
# Out:
# [('女人', 0.3762631547670275),
#  ('男人', 0.31236381770256955),
#  ('女儿', 0.12899043758270426),
#  ('儿子', -0.15782254841235327),
#  ('母亲', 0.15581335230101664),
#  ('父亲', -0.10171088926319555),
#  ('女孩', 0.38977043262413047),
#  ('男孩', 0.28320961958427193),
#  ('皇后', 0.35377867868584095),
#  ('国王', -0.178040549242833),
#  ('妻子', 0.1712903944941719),
#  ('丈夫', 0.21889256747401728),
#  ('女士', 0.24196375121334984),
#  ('先生', -0.12106016761355175),
#  ('外婆', 0.4097969322303501),
#  ('外公', 0.08360089604610628),
#  ('姥姥', 0.2209537448912796),
#  ('姥爷', 0.01731740863058685),
#  ('奶奶', 0.338015392169806),
#  ('爷爷', -0.041621903939498064),
#  ('舅妈', 0.23907706580193988),
#  ('舅舅', -0.022999808960057034),
#  ('阿姨', 0.3783665778777825),
#  ('姨父', 0.12230921961824104),
#  ('伯母', 0.3401301523748383),
#  ('伯伯', -0.02273544911666175),
#  ('婶婶', 0.1470421624809889),
#  ('叔叔', -0.1168965615995465),
#  ('姑姑', 0.30287941172644556),
#  ('姑父', -0.09426980862671719),
#  ('表姐', 0.3512006048809168),
# ...

# %%
# Adding more word pairs worsens the PCA scores a lot,
# Decided to cut more pairs
# Less is more

# %%
# Removing woman-man pair ['女人', '男人']
# PCA score improves, [0.54449336, 0.24973625, 0.07894514, 0.06443438, 0.03684415]
# 0.52368772 -> 0.54449336 = 0.02080564

REMOVING_WOMAN_MAN = [['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'], 
                      ['皇后', '国王'], ['妻子', '丈夫'], ['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, REMOVING_WOMAN_MAN, 5)
# Out:
# array([0.54449336, 0.24973625, 0.07894514, 0.06443438, 0.03684415])

# %%
WORD_PAIRS_FLAT = [item for pair in REMOVING_WOMAN_MAN for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, REMOVING_WOMAN_MAN, 0)
# Out:
# [('女儿', -0.10587219578676033),
#  ('儿子', -0.20695718510606637),
#  ('母亲', -0.05874224386487626),
#  ('父亲', -0.13600832808290333),
#  ('女孩', 0.06264015007558453),
#  ('男孩', 0.07873815777803339),
#  ('皇后', 0.4963575717551282),
#  ('国王', -0.4795021443267972),
#  ('妻子', 0.04917299507502306),
#  ('丈夫', 0.06892449714495644),
#  ('女士', 0.053106573834932044),
#  ('先生', 0.029946005577094266)]

# %%
# Removing daughter-son pair ['女儿', '儿子']
# PCA score improves, [0.56122288, 0.2399728 , 0.06745064, 0.06139032, 0.04182461]
# 0.52368772 -> 0.56122288 = 0.03753516

REMOVING_DAUGHTER_SON = [['女人', '男人'], ['母亲', '父亲'], ['女孩', '男孩'], 
                         ['皇后', '国王'], ['妻子', '丈夫'], ['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, REMOVING_DAUGHTER_SON, 5)
# Out:
# array([0.56122288, 0.2399728 , 0.06745064, 0.06139032, 0.04182461])

# %%
WORD_PAIRS_FLAT = [item for pair in REMOVING_DAUGHTER_SON for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, REMOVING_DAUGHTER_SON, 0)
# Out:
# [('女人', 0.016622877457780957),
#  ('男人', -0.014970736124506362),
#  ('母亲', -0.0660504650513922),
#  ('父亲', -0.13409164697313705),
#  ('女孩', 0.04748550041198859),
#  ('男孩', 0.07052489253777049),
#  ('皇后', 0.4961056342960573),
#  ('国王', -0.48112664385653087),
#  ('妻子', 0.04148923499870012),
#  ('丈夫', 0.059867785229287554),
#  ('女士', 0.03967374481257406),
#  ('先生', 0.03781809573759583)]

# %%
# Removing mother-father pair ['母亲', '父亲']
# PCA score improves, [0.55996887, 0.2463393 , 0.07372601, 0.05782006, 0.0361406]
# 0.52368772 -> 0.55996887 = 0.03628115

REMOVING_MOTHER_FATHER = [['女人', '男人'], ['女儿', '儿子'], ['女孩', '男孩'],
                          ['皇后', '国王'], ['妻子', '丈夫'], ['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, REMOVING_MOTHER_FATHER, 5)
# Out:
# array([0.55996887, 0.2463393 , 0.07372601, 0.05782006, 0.0361406 ])

# %%
WORD_PAIRS_FLAT = [item for pair in REMOVING_MOTHER_FATHER for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, REMOVING_MOTHER_FATHER, 0)
# Out:
# [('女人', -0.02220148426056472),
#  ('男人', 0.012083345564959231),
#  ('女儿', 0.11361926057854498),
#  ('儿子', 0.21011430607994303),
#  ('女孩', -0.05332496547535623),
#  ('男孩', -0.07120850124894),
#  ('皇后', -0.49189795129374814),
#  ('国王', 0.48476269012704837),
#  ('妻子', -0.04415496336947648),
#  ('丈夫', -0.06398719234869821),
#  ('女士', -0.04753286230520221),
#  ('先生', -0.034453455465967585)]

# %%
# Removing girl-boy pair ['女孩', '男孩']
# PCA score improves, [0.56210701, 0.24757079, 0.083535  , 0.04725971, 0.03555528]
# 0.52368772 -> 0.56210701 = 0.03841929

REMOVING_GIRL_BOY = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], 
                     ['皇后', '国王'], ['妻子', '丈夫'], ['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, REMOVING_GIRL_BOY, 5)
# Out:
# array([0.56210701, 0.24757079, 0.083535  , 0.04725971, 0.03555528])

# %%
WORD_PAIRS_FLAT = [item for pair in REMOVING_GIRL_BOY for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, REMOVING_GIRL_BOY, 0)
# Out:
# [('女人', -0.03122994029895388),
#  ('男人', 0.0034871650181225442),
#  ('女儿', 0.10499888751871878),
#  ('儿子', 0.2074997184902705),
#  ('母亲', 0.05832671305474499),
#  ('父亲', 0.13604536228156444),
#  ('皇后', -0.49669941032985276),
#  ('国王', 0.47894475381895557),
#  ('妻子', -0.049786056572164714),
#  ('丈夫', -0.06949705272069856),
#  ('女士', -0.05387529506061846),
#  ('先生', -0.029030473704288913)]

# %%
# Removing queen_king pair ['皇后', '国王']
# PCA score worsens [0.49930852, 0.17138828, 0.12886282, 0.08875924, 0.06562586]
# 0.52368772 -> 0.49930852 = -0.0243792

REMOVING_QUEEN_KING = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'],['女孩', '男孩'],
                       ['妻子', '丈夫'],['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, REMOVING_QUEEN_KING, 5)
# Out:
# array([0.49930852, 0.17138828, 0.12886282, 0.08875924, 0.06562586])

# %%
WORD_PAIRS_FLAT = [item for pair in REMOVING_QUEEN_KING for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, REMOVING_QUEEN_KING, 0)
# Out:
# [('女人', -0.28429453789340586),
#  ('男人', -0.270672968836187),
#  ('女儿', -0.1892104062451461),
#  ('儿子', 0.03374974317263935),
#  ('母亲', -0.18402268200569089),
#  ('父亲', 2.6030284606573077e-05),
#  ('女孩', -0.32852473690951656),
#  ('男孩', -0.14774375164982126),
#  ('妻子', -0.21982285090516035),
#  ('丈夫', -0.219426964537936),
#  ('女士', -0.42360369418612925),
#  ('先生', 0.34382608050529967)]

# %%
# Removing wife-husband pair ['妻子', '丈夫']
# PCA score improves, [0.53810239, 0.2466353 , 0.0800649 , 0.06308138, 0.04377524]
# 0.52368772 -> 0.53810239 = 0.01441467

REMOVING_WIFE_HUSBAND = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'],
                         ['皇后', '国王'], ['女士', '先生']]
compute_explained_variance_ratio(wiki2vec, REMOVING_WIFE_HUSBAND, 5)
# Out:
# array([0.53810239, 0.2466353 , 0.0800649 , 0.06308138, 0.04377524])

# %%
WORD_PAIRS_FLAT = [item for pair in REMOVING_WIFE_HUSBAND  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, REMOVING_WIFE_HUSBAND , 0)
# Out:
# [('女人', -0.030184027426574823),
#  ('男人', 0.004581695959999669),
#  ('女儿', 0.10416679114146656),
#  ('儿子', 0.2058807885564114),
#  ('母亲', 0.05790514281110943),
#  ('父亲', 0.1353372422238839),
#  ('女孩', -0.06193409346439008),
#  ('男孩', -0.07811416183866722),
#  ('皇后', -0.49683192500392176),
#  ('国王', 0.4789258116886004),
#  ('女士', -0.05353887048589961),
#  ('先生', -0.030355712075617356)]

# %%
# Removing madam_sir pair ['女士', '先生']
# PCA score improves, [0.65887376, 0.13845784, 0.07970763, 0.0545742 , 0.03957444]
# 0.52368772 -> 0.65887376 = -0.13518604

REMOVING_MADAM_SIR = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'],
                      ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, REMOVING_MADAM_SIR, 5 )
# Out:
# array([0.65887376, 0.13845784, 0.07970763, 0.0545742 , 0.03957444])

# %%
WORD_PAIRS_FLAT = [item for pair in REMOVING_MADAM_SIR  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, REMOVING_MADAM_SIR , 0)
# Out:
# [('女人', 0.027224386580674838),
#  ('男人', -0.007501595337502584),
#  ('女儿', -0.10724790752385821),
#  ('儿子', -0.20695097185020994),
#  ('母亲', -0.060482594558201035),
#  ('父亲', -0.1361558388007966),
#  ('女孩', 0.05841793308391438),
#  ('男孩', 0.07638793347951302),
#  ('皇后', 0.4954062662353066),
#  ('国王', -0.48070801385302714),
#  ('妻子', 0.04669743940331544),
#  ('丈夫', 0.06641179544598336)]

# %%
# Comnbine mother-father, girl-boy, queen-king, wife-husband
COMBINE_GOOD_4 = [['母亲', '父亲'], ['女孩', '男孩'], 
                 ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, COMBINE_GOOD_4 , 5)
# Out:
# array([7.62198027e-01, 1.07520968e-01, 9.13283011e-02, 3.89527039e-02,
#        2.35608442e-15])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_GOOD_4  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_GOOD_4 , 0)
# Out:
# [('母亲', -0.06656475481777606),
#  ('父亲', -0.13433730021092577),
#  ('女孩', 0.04776061875890417),
#  ('男孩', 0.071012701172801),
#  ('皇后', 0.49544546941616713),
#  ('国王', -0.48182424048724165),
#  ('妻子', 0.041077804080016586),
#  ('丈夫', 0.059601047546898815)]

# %%
# Comnbine mother-father, girl-boy
COMBINE_1 = [['母亲', '父亲'], ['女孩', '男孩']]
compute_explained_variance_ratio(wiki2vec, COMBINE_1 , 2)
# Out:
# array([0.53790331, 0.46209669])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_1  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_1 , 0)
# Out:
# [('母亲', 0.21381059746019634),
#  ('父亲', -0.07396934962763768),
#  ('女孩', 0.38739517896195647),
#  ('男孩', 0.06204886131451584)]

# %%
# Comnbine mother-father, queen-king
COMBINE_2 = [['母亲', '父亲'], ['皇后', '国王']]
compute_explained_variance_ratio(wiki2vec, COMBINE_2 , 2)
# Out:
# array([0.88611458, 0.11388542])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_2  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_2 , 0)
# Out:
# [('母亲', -0.06622537338536408),
#  ('父亲', -0.1343190674130873),
#  ('皇后', 0.49518236589505304),
#  ('国王', -0.4820967319831199)]

# %%
# Comnbine mother-father, wife-husband
COMBINE_3 = [['母亲', '父亲'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, COMBINE_3 , 2)
# Out:
# array([0.71704756, 0.28295244])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_3  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_3 , 0)
# Out:
# [('母亲', 0.350713958154137),
#  ('父亲', -0.046508024858906774),
#  ('妻子', 0.18456483801898205),
#  ('丈夫', 0.1696505249331884)]

# %%
# Comnbine girl-boy, queen-king
COMBINE_4 = [['女孩', '男孩'], ['皇后', '国王']]
compute_explained_variance_ratio(wiki2vec, COMBINE_4 , 2)
# Out:
# array([0.883349, 0.116651])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_4  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_4 , 0)
# Out:
# [('女孩', 0.0417723225201202),
#  ('男孩', 0.06584119321989512),
#  ('皇后', 0.4913723711069534),
#  ('国王', -0.4860859863774765)]

# %%
# Comnbine girl-boy, wife-husband
COMBINE_5 = [['女孩', '男孩'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, COMBINE_5 , 2)
# Out:
# array([0.71919086, 0.28080914])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_5  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_5 , 0)
# Out:
# [('女孩', -0.26524447919201827),
#  ('男孩', 0.17449586658109542),
#  ('妻子', -0.049155542003940705),
#  ('丈夫', -0.08035497683548508)]

# %%
# Comnbine queen-king, wife-husband
COMBINE_6 = [['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, COMBINE_6 , 2)
# Out:
# array([0.95060329, 0.04939671])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_6  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_6 , 0)
# Out:
# [('皇后', -0.49108096329514594),
#  ('国王', 0.4863966151725007),
#  ('妻子', -0.03807070494608154),
#  ('丈夫', -0.05693686632719262)]

# %%
# Comnbine mother-father, girl-boy, queen-king
COMBINE_7 = [['母亲', '父亲'], ['女孩', '男孩'], ['皇后', '国王']]
compute_explained_variance_ratio(wiki2vec, COMBINE_7 , 2)
# Out:
# array([0.79351382, 0.11194665])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_7  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_7 , 0)
# Out:
# [('母亲', -0.06607668173005167),
#  ('父亲', -0.13389692868099257),
#  ('女孩', 0.04774235316145403),
#  ('男孩', 0.071093644644373),
#  ('皇后', 0.49545025019034017),
#  ('国王', -0.48181885445804995)]

# %%
# Comnbine mother-father, girl-boy, wife-husband
COMBINE_8 = [['母亲', '父亲'], ['女孩', '男孩'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, COMBINE_8 , 2)
# Out:
# array([0.4491884 , 0.38763899])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_8  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_8 , 0)
# Out:
# [('母亲', 0.21164148560219045),
#  ('父亲', -0.07507543481009764),
#  ('女孩', 0.3872815806170795),
#  ('男孩', 0.06073846960619856),
#  ('妻子', 0.157181654906387),
#  ('丈夫', 0.16905174222062871)]

# %%
# Comnbine mother-father, queen-king, wife-husband
COMBINE_9 = [['母亲', '父亲'], ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, COMBINE_9, 2)
# Out:
# array([0.84721796, 0.10909367])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_9  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_9 , 0)
# Out:
# [('母亲', -0.06671649938377994),
#  ('父亲', -0.1347607371279002),
#  ('皇后', 0.49517809879283914),
#  ('国王', -0.4821001941167981),
#  ('妻子', 0.04149409768670244),
#  ('丈夫', 0.06016153388837593)]

# %%
# Comnbine girl-boy, queen-king, wife-husband
COMBINE_10 = [['女孩', '男孩'], ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, COMBINE_10 , 2)
# Out:
# array([0.84460706, 0.11181744])

# %%
WORD_PAIRS_FLAT = [item for pair in COMBINE_10  for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINE_10, 0)
# Out:
# [('女孩', 0.04179951146627025),
#  ('男孩', 0.06576581311939043),
#  ('皇后', 0.49137161761150644),
#  ('国王', -0.4860835838101978),
#  ('妻子', 0.037652698689097326),
#  ('丈夫', 0.056367640771524695)]

# %%
'''

Summary of removing each pair at a time

Worsens means it's better to keep
Order by positive to negative, better to remove

Pair                                  Weight (+improves, -worsens)
__________________________________________________________________

madam_sir ['女士', '先生']             0.13518604
girl-boy ['女孩', '男孩']              0.03841929
daughter-son ['女儿', '儿子']          0.03753516
mother-father ['母亲', '父亲']         0.03628115
woman-man ['女人', '男人']             0.02080564
wife-husband ['妻子', '丈夫']          0.01441467
queen_king ['皇后', '国王']            -0.0243792

'''
# Out:
# "\n\nSummary of removing each pair at a time\n\nWorsens means it's better to keep\nOrder by positive to negative, better to remove\n\nPair                                  Weight (+improves, -worsens)\n__________________________________________________________________\n\nmadam_sir ['女士', '先生']             0.13518604\ngirl-boy ['女孩', '男孩']              0.03841929\ndaughter-son ['女儿', '儿子']          0.03753516\nmother-father ['母亲', '父亲']         0.03628115\nwoman-man ['女人', '男人']             0.02080564\nwife-husband ['妻子', '丈夫']          0.01441467\nqueen_king ['皇后', '国王']            -0.0243792\n\n"

# %%
'''
  NEW_WORD_PAIRS_TO_BEGIN
* Removing madam_sir pair ['女士', '先生'] solely gives the highest PCA,
  [0.65887376, 0.13845784, 0.07970763, 0.0545742 , 0.03957444]
  
  NEW_WORD_PAIRS_1
* Removing girl_boy pair ['女孩', '男孩'] on top of that,
  improves by 0.68188983 -> 0.72087552 = 0.03898569
  [0.72087552, 0.14021203, 0.06085562, 0.04608681, 0.03197002]
  
  NEW_WORD_PAIRS_2
* Removing daughter_son pair ['女儿', '儿子'] on top of that,
  improves by 0.72087552 -> 0.797051513 = 0.076175993
  [7.97051513e-01, 1.02683991e-01, 5.96355847e-02, 4.06289108e-02, 2.51287560e-15]

  NEW_WORD_PAIRS_3
* Removing mother_father pair ['母亲', '父亲'] on top of that,
  improves by 0.797051513 -> 0.887673308 = 0.090621795
  [8.87673308e-01, 6.67758232e-02, 4.55508684e-02, 2.86169591e-15, 2.13270562e-15]  
  
  NEW_WORD_PAIRS_4
* Removing woman-man pair ['女人', '男人'] on top of that,
  improves by 0.887673308 -> 0.95060329 = 0.062929982 

  QUEEN_KING (['皇后', '国王'])
* Removing wife-husband pair ['妻子', '丈夫']  on top of that,
  PCA is 1, but score doesn't reflect clear gender direction
   ('皇后', -0.49108096329514594)  - queen
   ('国王', 0.4863966151725007)    - king
  
  KING_QUEEN ['国王', '皇后']  
* PCA is 1, and score reflects better gender direction 
   ('国王', -0.48640125002375717)  - king
   ('皇后', 0.4910811142605316)    - queen
  
* PCA is 1 when there is only one word pair

  MOM_DAD ['妈妈', '爸爸']
   ('妈妈', 0.4530961979739654)    -mom
   ('爸爸', -0.20034860438449645)  -dad
   
  FEMALE_MALE = [['女', '男']]
   ('女', 0.15133444811826505)    -female
   ('男', -0.39201177662567943)   -male
   
   HER_HIM
   ('她', 0.4629544447289977)     -her
   ('他', -0.07592389461344515)   -him


'''
NEW_WORD_PAIRS_TO_BEGIN = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], ['女孩', '男孩'],
                           ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, NEW_WORD_PAIRS_TO_BEGIN, 5)
# Out:
# array([0.65887376, 0.13845784, 0.07970763, 0.0545742 , 0.03957444])

# %%
WORD_PAIRS_FLAT = [item for pair in NEW_WORD_PAIRS_TO_BEGIN for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, NEW_WORD_PAIRS_TO_BEGIN, 0)
# Out:
# [('女人', 0.027224386580674838),
#  ('男人', -0.007501595337502584),
#  ('女儿', -0.10724790752385821),
#  ('儿子', -0.20695097185020994),
#  ('母亲', -0.060482594558201035),
#  ('父亲', -0.1361558388007966),
#  ('女孩', 0.05841793308391438),
#  ('男孩', 0.07638793347951302),
#  ('皇后', 0.4954062662353066),
#  ('国王', -0.48070801385302714),
#  ('妻子', 0.04669743940331544),
#  ('丈夫', 0.06641179544598336)]

# %%
NEW_WORD_PAIRS_1 = [['女人', '男人'], ['女儿', '儿子'], ['母亲', '父亲'], 
                    ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, NEW_WORD_PAIRS_1, 5)
# Out:
# array([0.72087552, 0.14021203, 0.06085562, 0.04608681, 0.03197002])

# %%
WORD_PAIRS_FLAT = [item for pair in NEW_WORD_PAIRS_1 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, NEW_WORD_PAIRS_1, 0)
# Out:
# [('女人', -0.028025692142282756),
#  ('男人', 0.006718678270958149),
#  ('女儿', 0.10728109756404895),
#  ('儿子', 0.20758757103599354),
#  ('母亲', 0.06055564163057039),
#  ('父亲', 0.1364746453974281),
#  ('皇后', -0.49517326163809783),
#  ('国王', 0.48087933205613026),
#  ('妻子', -0.0470382672978392),
#  ('丈夫', -0.0668667668369455)]

# %%
NEW_WORD_PAIRS_2 = [['女人', '男人'], ['母亲', '父亲'], 
                    ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, NEW_WORD_PAIRS_2, 5)
# Out:
# array([7.97051513e-01, 1.02683991e-01, 5.96355847e-02, 4.06289108e-02,
#        2.51287560e-15])

# %%
WORD_PAIRS_FLAT = [item for pair in NEW_WORD_PAIRS_2 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, NEW_WORD_PAIRS_2, 0)
# Out:
# [('女人', 0.017253096856800095),
#  ('男人', -0.014351760120614052),
#  ('母亲', -0.06644442679352872),
#  ('父亲', -0.13456071207506173),
#  ('皇后', 0.4956425781604114),
#  ('国王', -0.48160625574147636),
#  ('妻子', 0.04159207899430888),
#  ('丈夫', 0.06012964500941758)]

# %%
NEW_WORD_PAIRS_3 = [['女人', '男人'], ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, NEW_WORD_PAIRS_3, 5)
# Out:
# array([8.87673308e-01, 6.67758232e-02, 4.55508684e-02, 2.86169591e-15,
#        2.13270562e-15])

# %%
WORD_PAIRS_FLAT = [item for pair in NEW_WORD_PAIRS_3 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, NEW_WORD_PAIRS_3, 0)
# Out:
# [('女人', -0.011601003857849483),
#  ('男人', 0.01972039342524328),
#  ('皇后', -0.491542903563301),
#  ('国王', 0.4859096495744731),
#  ('妻子', -0.038165946056102115),
#  ('丈夫', -0.0569028637716131)]

# %%
NEW_WORD_PAIRS_4 = [['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, NEW_WORD_PAIRS_4, 1)
# Out:
# array([0.95060329])

# %%
WORD_PAIRS_FLAT = [item for pair in NEW_WORD_PAIRS_4 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, NEW_WORD_PAIRS_4, 0)
# Out:
# [('皇后', -0.49108096329514594),
#  ('国王', 0.4863966151725007),
#  ('妻子', -0.03807070494608154),
#  ('丈夫', -0.05693686632719262)]

# %%
QUEEN_KING = [['皇后', '国王']]
WORD_PAIRS_FLAT = [item for pair in QUEEN_KING for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, QUEEN_KING, 0)
# Out:
# [('皇后', -0.4910811142605316), ('国王', 0.48640125002375717)]

# %%
KING_QUEEN = [['国王','皇后']]
WORD_PAIRS_FLAT = [item for pair in KING_QUEEN for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, KING_QUEEN, 0)
# Out:
# [('国王', -0.48640125002375717), ('皇后', 0.4910811142605316)]

# %%
MOM_DAD = [['妈妈', '爸爸']]
WORD_PAIRS_FLAT = [item for pair in MOM_DAD for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, MOM_DAD, 0)
# Out:
# [('妈妈', 0.4530961979739654), ('爸爸', -0.20034860438449645)]

# %%
FEMALE_MALE = [['女', '男']]
WORD_PAIRS_FLAT = [item for pair in FEMALE_MALE for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, FEMALE_MALE, 0)
# Out:
# [('女', 0.15133444811826505), ('男', -0.39201177662567943)]

# %%
HER_HIM = [['她', '他']]
WORD_PAIRS_FLAT = [item for pair in HER_HIM for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, HER_HIM, 0)
# Out:
# [('她', 0.4629544447289977), ('他', -0.07592389461344515)]

# %%
MOTHER_IN_LAW_FATHER_IN_LAW = [['婆婆', '公公']]
WORD_PAIRS_FLAT = [item for pair in MOTHER_IN_LAW_FATHER_IN_LAW for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, MOTHER_IN_LAW_FATHER_IN_LAW, 0)
# Out:
# [('婆婆', 0.4113477305637571), ('公公', -0.40357826294953536)]

# %%
'''

1 MOM_DAD = ['妈妈', '爸爸']
2 FEMALE_MALE = ['女', '男']
3 HER_HIM = ['她', '他']
4 MOTHER_IN_LAW_FATHER_IN_LAW = ['婆婆', '公公']

COMBINED_1: 1&2         Correct direction     PCA0: 0.5474449     PCA0-PCA1: 0.0948898
COMBINED_2: 1&3         Incorrect direction   PCA0: 0.73662917    PCA0-PCA1: 0.47325834
COMBINED_3: 1&4         Incorrect direction   PCA0: 0.58769328    PCA0-PCA1: 0.17538656
COMBINED_4: 2&3         Correct direction     PCA0: 0.71550695    PCA0-PCA1: 0.4310139
COMBINED_5: 2&4         Incorrect direction   PCA0: 0.65868575    PCA0-PCA1: 0.3173715
COMBINED_6: 3&4         Incorrect direction   PCA0: 0.79847044    PCA0-PCA1: 0.59694088
COMBINED_7: 1&2&3       Correct direction     PCA0: 0.46022038    PCA0-PCA1: 0.07535539
COMBINED_8: 1&2&4       Incorrect direction   PCA0: 0.4570290     PCA0-PCA1: 0.14751641
COMBINED_9: 2&3&4       Incorrect direction   PCA0: 0.56825253    PCA0-PCA1: 0.26448299
COMBINED_10: 1&2&3&4    Incorrect direction   PCA0: 0.41164242    PCA0-PCA1: 0.13162229
'''
# Out:
# "\n\n1 MOM_DAD = ['妈妈', '爸爸']\n2 FEMALE_MALE = ['女', '男']\n3 HER_HIM = ['她', '他']\n4 MOTHER_IN_LAW_FATHER_IN_LAW = ['婆婆', '公公']\n\nCOMBINED_1: 1&2         Correct direction     PCA0: 0.5474449     PCA0-PCA1: 0.0948898\nCOMBINED_2: 1&3         Incorrect direction   PCA0: 0.73662917    PCA0-PCA1: 0.47325834\nCOMBINED_3: 1&4         Incorrect direction   PCA0: 0.58769328    PCA0-PCA1: 0.17538656\nCOMBINED_4: 2&3         Correct direction     PCA0: 0.71550695    PCA0-PCA1: 0.4310139\nCOMBINED_5: 2&4         Incorrect direction   PCA0: 0.65868575    PCA0-PCA1: 0.3173715\nCOMBINED_6: 3&4         Incorrect direction   PCA0: 0.79847044    PCA0-PCA1: 0.59694088\nCOMBINED_7: 1&2&3       Correct direction     PCA0: 0.46022038    PCA0-PCA1: 0.07535539\nCOMBINED_8: 1&2&4       Incorrect direction   PCA0: 0.4570290     PCA0-PCA1: 0.14751641\nCOMBINED_9: 2&3&4       Incorrect direction   PCA0: 0.56825253    PCA0-PCA1: 0.26448299\nCOMBINED_10: 1&2&3&4    Incorrect direction   PCA0: 0.41164242    PCA
# ...

# %%
'''

COMBINED_1: MOM_DAD ['妈妈', '爸爸'], FEMALE_MALE ['女', '男']

Right direction

[('妈妈', 0.43139620393392913),
 ('爸爸', -0.20855619772507003),
 ('女', 0.0852621426705915),
 ('男', -0.05493863175347276)]

 PCA: 0.5474449
 
'''
COMBINED_1 = [['妈妈', '爸爸'], ['女', '男']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_1 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_1, 0)
# Out:
# [('妈妈', 0.43139620393392913),
#  ('爸爸', -0.20855619772507003),
#  ('女', 0.0852621426705915),
#  ('男', -0.05493863175347276)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_1, 2)
# Out:
# array([0.5474449, 0.4525551])

# %%
'''

COMBINED_2: MOM_DAD ['妈妈', '爸爸'], HER_HIM = ['她', '他']

Wrong direction

[('妈妈', -0.46151028156344914),
 ('爸爸', 0.19075171563827176),
 ('她', -0.03633682703361931),
 ('他', 0.01175875042754669)]

 PCA: 0.73662917
 
'''
COMBINED_2 = [['妈妈', '爸爸'], ['她', '他']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_2 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_2, 0)
# Out:
# [('妈妈', -0.46151028156344914),
#  ('爸爸', 0.19075171563827176),
#  ('她', -0.03633682703361931),
#  ('他', 0.01175875042754669)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_2, 2)
# Out:
# array([0.73662917, 0.26337083])

# %%
'''

COMBINED_3: MOM_DAD ['妈妈', '爸爸'], MOTHER_IN_LAW_FATHER_IN_LAW = ['婆婆', '公公']

Wrong direction

[('妈妈', -0.0780053342095804),
 ('爸爸', -0.008835433169069061),
 ('婆婆', -0.4010137874301604),
 ('公公', 0.4114963445074019)]

 PCA: 0.58769328
 
'''
COMBINED_3 = [['妈妈', '爸爸'], ['婆婆', '公公']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_3 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_3, 0)
# Out:
# [('妈妈', -0.0780053342095804),
#  ('爸爸', -0.008835433169069061),
#  ('婆婆', -0.4010137874301604),
#  ('公公', 0.4114963445074019)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_3, 2)
# Out:
# array([0.58769328, 0.41230672])

# %%
'''

COMBINED_4: FEMALE_MALE ['女', '男'], HER_HIM = ['她', '他']

Right direction

[('女', 0.18093726794739198),
 ('男', -0.3607881898535497),
 ('她', 0.1494643385017495),
 ('他', -0.0016640412365194327)]

 PCA: 0.71550695
 
'''
COMBINED_4 = [['女', '男'], ['她', '他']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_4 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_4, 0)
# Out:
# [('女', 0.18093726794739198),
#  ('男', -0.3607881898535497),
#  ('她', 0.1494643385017495),
#  ('他', -0.0016640412365194327)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_4, 2)
# Out:
# array([0.71550695, 0.28449305])

# %%
'''

COMBINED_5: FEMALE_MALE ['女', '男'],  MOTHER_IN_LAW_FATHER_IN_LAW = ['婆婆', '公公']]

Weird direction

[('女', 0.023211614181361275),
 ('男', -0.20294269757204308),
 ('婆婆', -0.3693174744158217),
 ('公公', 0.4230818748164344)]

 PCA: 0.65868575
 
'''
COMBINED_5 = [['女', '男'], ['婆婆', '公公']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_5 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_5, 0)
# Out:
# [('女', 0.023211614181361275),
#  ('男', -0.20294269757204308),
#  ('婆婆', -0.3693174744158217),
#  ('公公', 0.4230818748164344)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_5, 2)
# Out:
# array([0.65868575, 0.34131425])

# %%
'''

COMBINED_6:  HER_HIM = ['她', '他'],  MOTHER_IN_LAW_FATHER_IN_LAW = ['婆婆', '公公']]

Wrong direction

[('她', -0.026129173038587347),
 ('他', 0.021328355403508033),
 ('婆婆', -0.41760453129877395),
 ('公公', 0.3971084590161871)]

 PCA: 0.79847044
 
'''
COMBINED_6 = [['她', '他'], ['婆婆', '公公']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_6 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_6, 0)
# Out:
# [('她', -0.026129173038587347),
#  ('他', 0.021328355403508033),
#  ('婆婆', -0.41760453129877395),
#  ('公公', 0.3971084590161871)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_6, 2)
# Out:
# array([0.79847044, 0.20152956])

# %%
'''

COMBINED_7:  MOM_DAD = ['妈妈', '爸爸'], FEMALE_MALE = ['女', '男'], HER_HIM = ['她', '他']

Wrong direction

[('妈妈', 0.4384788990661791),
 ('爸爸', -0.19250238844503875),
 ('女', 0.1045801790138178),
 ('男', -0.05997760536868374),
 ('她', 0.06889783849114917),
 ('他', -0.011067158817119237)]

 PCA: 0.79847044
 
'''
COMBINED_7 = [['妈妈', '爸爸'], ['女', '男'], ['她', '他']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_7 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_7, 0)
# Out:
# [('妈妈', 0.4384788990661791),
#  ('爸爸', -0.19250238844503875),
#  ('女', 0.1045801790138178),
#  ('男', -0.05997760536868374),
#  ('她', 0.06889783849114917),
#  ('他', -0.011067158817119237)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_7, 2)
# Out:
# array([0.46022038, 0.38486499])

# %%
'''

COMBINED_8:  MOM_DAD = ['妈妈', '爸爸'], FEMALE_MALE = ['女', '男'], MOTHER_IN_LAW_FATHER_IN_LAW = ['婆婆', '公公']

Wrong direction

[('妈妈', -0.0669288318184419),
 ('爸爸', -0.03062613007222887),
 ('女', 0.02050831985747288),
 ('男', -0.2029323158398414),
 ('婆婆', -0.364966898566944),
 ('公公', 0.42768906856409644)]

 
'''
COMBINED_8 = [['妈妈', '爸爸'], ['女', '男'], ['婆婆', '公公']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_8 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_8, 0)
# Out:
# [('妈妈', -0.0669288318184419),
#  ('爸爸', -0.03062613007222887),
#  ('女', 0.02050831985747288),
#  ('男', -0.2029323158398414),
#  ('婆婆', -0.364966898566944),
#  ('公公', 0.42768906856409644)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_8, 2)
# Out:
# array([0.45702906, 0.30951265])

# %%
'''

COMBINED_9: FEMALE_MALE = ['女', '男'], HER_HIM = ['她', '他'], MOTHER_IN_LAW_FATHER_IN_LAW = ['婆婆', '公公']

Wrong direction

[('女', 0.021356581707709186),
 ('男', -0.20351317735189625),
 ('她', 0.005373565196341872),
 ('他', 0.020496010263221547),
 ('婆婆', -0.37142421600846176),
 ('公公', 0.42140728889801926)]

 
'''
COMBINED_9 = [['女', '男'],  ['她', '他'], ['婆婆', '公公']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_9 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_9, 0)
# Out:
# [('女', 0.021356581707709186),
#  ('男', -0.20351317735189625),
#  ('她', 0.005373565196341872),
#  ('他', 0.020496010263221547),
#  ('婆婆', -0.37142421600846176),
#  ('公公', 0.42140728889801926)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_9, 2)
# Out:
# array([0.56825253, 0.30376954])

# %%
COMBINED_10 = [['妈妈', '爸爸'], ['女', '男'],  ['她', '他'], ['婆婆', '公公']]
WORD_PAIRS_FLAT = [item for pair in COMBINED_10 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, COMBINED_10, 0)
# Out:
# [('妈妈', -0.06933177896620772),
#  ('爸爸', -0.032297891979132375),
#  ('女', 0.018301977167495896),
#  ('男', -0.2035827775485403),
#  ('她', 0.0037357637433982557),
#  ('他', 0.020927560884518165),
#  ('婆婆', -0.36728633063854593),
#  ('公公', 0.42583504577478815)]

# %%
compute_explained_variance_ratio(wiki2vec, COMBINED_10, 2)
# Out:
# array([0.41164242, 0.28002013])

# %%
Test1 = [['妈妈', '爸爸'], ['女人', '男人']]
WORD_PAIRS_FLAT = [item for pair in Test1 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, Test1, 0)
# Out:
# [('妈妈', 0.4482926786831321),
#  ('爸爸', -0.20488583815296169),
#  ('女人', 0.031100357683881745),
#  ('男人', -0.04523319688200765)]

# %%
compute_explained_variance_ratio(wiki2vec, Test1, 2)
# Out:
# array([0.83815458, 0.16184542])

# %%
Test2 = [['女人', '男人'], ['她', '他'], ['妈妈', '爸爸']]
WORD_PAIRS_FLAT = [item for pair in Test2 for item in pair]
bias_by_word(wiki2vec, WORD_PAIRS_FLAT, Test2, 0)
# Out:
# [('女人', -0.04484798841539145),
#  ('男人', 0.03270710519697136),
#  ('她', -0.03515495958790072),
#  ('他', 0.016243005450868316),
#  ('妈妈', -0.4570038579565412),
#  ('爸爸', 0.1948218884014007)]

# %%
ORIGINAL_WORD_PAIRS = ['女人', '男人', '女儿', '儿子', '母亲', '父亲', '女孩', '男孩', '皇后', '国王', 
                       '妻子', '丈夫', '女士', '先生']

# %%
'''
6 new defining set on original definig set

1. female-male, her-him [['女','男'], ['她','他']]
2. mother-father, queen-king [['母亲', '父亲'], ['皇后', '国王']]
3. mother-father, girl-boy, queen-king [['母亲', '父亲'], ['女孩', '男孩'], ['皇后', '国王']]
5. mother-father, queen-king, wife-husband [['母亲', '父亲'], ['皇后', '国王'], ['妻子', '丈夫']]
5. mother-father, girl-boy, queen-king, wife-husband [['母亲', '父亲'], ['女孩', '男孩'], ['皇后', '国王'], ['妻子', '丈夫']]
6. mom-dad, woman-man [['妈妈', '爸爸'], ['女人', '男人']]

'''
# Out:
# "\n6 new defining set on original definig set\n\n1. female-male, her-him [['女','男'], ['她','他']]\n2. mother-father, queen-king [['母亲', '父亲'], ['皇后', '国王']]\n3. mother-father, girl-boy, queen-king [['母亲', '父亲'], ['女孩', '男孩'], ['皇后', '国王']]\n5. mother-father, queen-king, wife-husband [['母亲', '父亲'], ['皇后', '国王'], ['妻子', '丈夫']]\n5. mother-father, girl-boy, queen-king, wife-husband [['母亲', '父亲'], ['女孩', '男孩'], ['皇后', '国王'], ['妻子', '丈夫']]\n6. mom-dad, woman-man [['妈妈', '爸爸'], ['女人', '男人']]\n\n"

# %%
# 1. female-male, her-him
New1of6 = [['女','男'], ['她','他']]
compute_explained_variance_ratio(wiki2vec, New1of6 , 2)
# Out:
# array([0.71550695, 0.28449305])

# %%
bias_by_word(wiki2vec, ORIGINAL_WORD_PAIRS, New1of6, 0)
# Out:
# [('女人', -0.0389975123283721),
#  ('男人', -0.059903018039262186),
#  ('女儿', 0.2522658632746773),
#  ('儿子', 0.1777272240205952),
#  ('母亲', 0.2703153302995423),
#  ('父亲', 0.2199239036019828),
#  ('女孩', -0.006474383743350582),
#  ('男孩', -0.04431618296783353),
#  ('皇后', 0.22464298712266212),
#  ('国王', 0.09774912837403375),
#  ('妻子', 0.2732625388635829),
#  ('丈夫', 0.24931702781325482),
#  ('女士', 0.1735311321932561),
#  ('先生', -0.04817718938494719)]

# %%
# 2. Combine mother-father, queen-king
New2of6 = [['母亲', '父亲'], ['皇后', '国王']]
compute_explained_variance_ratio(wiki2vec, New2of6 , 2)
# Out:
# array([0.88611458, 0.11388542])

# %%
bias_by_word(wiki2vec, ORIGINAL_WORD_PAIRS, New2of6, 0)
# Out:
# [('女人', 0.016332018850474812),
#  ('男人', -0.012986637705115007),
#  ('女儿', -0.11515462381508931),
#  ('儿子', -0.2004185798093143),
#  ('母亲', -0.06622537338536408),
#  ('父亲', -0.1343190674130873),
#  ('女孩', 0.04953945326227971),
#  ('男孩', 0.0699844199694209),
#  ('皇后', 0.49518236589505304),
#  ('国王', -0.4820967319831199),
#  ('妻子', 0.04233869200467391),
#  ('丈夫', 0.06015515979620938),
#  ('女士', 0.040470387861813),
#  ('先生', 0.03792976319685233)]

# %%
# 3. Combine mother-father, girl-boy, queen-king 
New3of6 = [['母亲', '父亲'], ['女孩', '男孩'], ['皇后', '国王']]
compute_explained_variance_ratio(wiki2vec, New3of6 , 2)
# Out:
# array([0.79351382, 0.11194665])

# %%
bias_by_word(wiki2vec, ORIGINAL_WORD_PAIRS, New3of6, 0)
# Out:
# [('女人', 0.01533946050863844),
#  ('男人', -0.013976648811615942),
#  ('女儿', -0.11504024953673682),
#  ('儿子', -0.19960186174241298),
#  ('母亲', -0.06607668173005167),
#  ('父亲', -0.13389692868099257),
#  ('女孩', 0.04774235316145403),
#  ('男孩', 0.071093644644373),
#  ('皇后', 0.49545025019034017),
#  ('国王', -0.48181885445804995),
#  ('妻子', 0.04191379162404571),
#  ('丈夫', 0.059592029177486655),
#  ('女士', 0.0397225442872296),
#  ('先生', 0.03878925430754637)]

# %%
# 4. Combine mother-father, queen-king, wife-husband
New4of6 = [['母亲', '父亲'], ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, New4of6 , 2)
# Out:
# array([0.84721796, 0.10909367])

# %%
bias_by_word(wiki2vec, ORIGINAL_WORD_PAIRS, New4of6, 0)
# Out:
# [('女人', 0.016452148432162837),
#  ('男人', -0.012808135333129425),
#  ('女儿', -0.11608597402081085),
#  ('儿子', -0.20144910652150327),
#  ('母亲', -0.06671649938377994),
#  ('父亲', -0.1347607371279002),
#  ('女孩', 0.04954940251971805),
#  ('男孩', 0.06990791108060222),
#  ('皇后', 0.49517809879283914),
#  ('国王', -0.4821001941167981),
#  ('妻子', 0.04149409768670244),
#  ('丈夫', 0.06016153388837593),
#  ('女士', 0.03991853050433406),
#  ('先生', 0.03751702717419303)]

# %%
# 5. Combine mother-father, girl-boy, queen-king, wife-husband 
New5of6 = [['母亲', '父亲'], ['女孩', '男孩'], ['皇后', '国王'], ['妻子', '丈夫']]
compute_explained_variance_ratio(wiki2vec, New5of6 , 2)
# Out:
# array([0.76219803, 0.10752097])

# %%
bias_by_word(wiki2vec, ORIGINAL_WORD_PAIRS, New5of6, 0)
# Out:
# [('女人', 0.015463278135368025),
#  ('男人', -0.01379496582608598),
#  ('女儿', -0.11596502861598493),
#  ('儿子', -0.20062841842590015),
#  ('母亲', -0.06656475481777606),
#  ('父亲', -0.13433730021092577),
#  ('女孩', 0.04776061875890417),
#  ('男孩', 0.071012701172801),
#  ('皇后', 0.49544546941616713),
#  ('国王', -0.48182424048724165),
#  ('妻子', 0.041077804080016586),
#  ('丈夫', 0.059601047546898815),
#  ('女士', 0.039178505109192296),
#  ('先生', 0.038375804398198314)]

# %%
# 6. Combine mom-dad, woman-man
New6of6 = [['妈妈', '爸爸'], ['女人', '男人']]
compute_explained_variance_ratio(wiki2vec, New6of6 , 2)
# Out:
# array([0.83815458, 0.16184542])

# %%
bias_by_word(wiki2vec, ORIGINAL_WORD_PAIRS, New6of6, 0)
# Out:
# [('女人', 0.031100357683881745),
#  ('男人', -0.04523319688200765),
#  ('女儿', 0.32059411135724014),
#  ('儿子', 0.27950579030954875),
#  ('母亲', 0.37417328728972793),
#  ('父亲', 0.2753000978694879),
#  ('女孩', -0.0083975766033512),
#  ('男孩', 0.0866633528172151),
#  ('皇后', 0.04286482515869812),
#  ('国王', 0.28294948726212177),
#  ('妻子', -0.05415610643090891),
#  ('丈夫', -0.049521357140869554),
#  ('女士', -0.03742937919440834),
#  ('先生', -0.0959819277024474)]

# %%
NEUTRAL_WORDS = ['护士', '教师', '作家', '工程师', '科学家', '经理', 
                 '司机', '银行家', '电工', '酒保', '音乐家', '艺术家',
                 '厨师', '制片人', '法官', '喜剧演员', '发明家', '工人',
                 '战士', '记者', '学生',  '运动员',  '演员',  '总督', 
                 '农民', '人', '律师', '冒险家', '助手', '大使', 
                 '分析员', '宇航员',  '天文学家',  '生物学家']

# %%
bias_by_word(wiki2vec, NEUTRAL_WORDS, Test1, 0)
# Out:
# [('护士', 0.3426142928415389),
#  ('教师', 0.34504722773517904),
#  ('作家', -0.03396156149028852),
#  ('工程师', 0.29295000437155855),
#  ('科学家', 0.34511733327416666),
#  ('经理', 0.3077362704019521),
#  ('司机', 0.34715323045176033),
#  ('银行家', 0.23918616860634476),
#  ('电工', 0.2324997294419454),
#  ('酒保', -0.0709091799221771),
#  ('音乐家', 0.3825966461304016),
#  ('艺术家', 0.39193589606286133),
#  ('厨师', 0.35715240008077304),
#  ('制片人', 0.2003448407117809),
#  ('法官', -0.07642097071695239),
#  ('喜剧演员', 0.2814705058695979),
#  ('发明家', 0.263522100521533),
#  ('工人', -0.029164477097851426),
#  ('战士', 0.2772924147462774),
#  ('记者', 0.3675274279240111),
#  ('学生', 0.33408981223446615),
#  ('运动员', 0.27522484922328383),
#  ('演员', 0.3004133440217356),
#  ('总督', 0.30111722125697993),
#  ('农民', 0.34318211446657276),
#  ('人', 0.0681781509837962),
#  ('律师', 0.25277394440410345),
#  ('冒险家', 0.3364787505268849),
#  ('助手', -0.16673924713668),
#  ('大使', 0.006124260676904608),
#  ('分析员', 0.2125303334119509),
# ...
